# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.common.exceptions import NoSuchElementException, NoSuchWindowException
from selectorlib import Extractor
import bs4
from bs4 import BeautifulSoup
import requests
import json
import time
import urllib.request
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.action_chains import ActionChains
import csv
import pandas as pd
import numpy as np
from datetime import date

# %%
ChromeOptions = webdriver.ChromeOptions()
ChromeOptions.add_argument('ignore-certificate-errors')
driver = webdriver.Chrome(ChromeDriverManager().install(), options=ChromeOptions)
# Out:
# [WDM] - Current google-chrome version is 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Get LATEST driver version for 87.0.4280
# [WDM] - Trying to download new driver from http://chromedriver.storage.googleapis.com/87.0.4280.88/chromedriver_mac64.zip
# [WDM] - Driver has been saved in cache [/Users/ericroberts/.wdm/drivers/chromedriver/mac64/87.0.4280.88]

# %%
url = "https://www.whoscored.com/Regions/252/Tournaments/2/Seasons/8228/Stages/18685/PlayerStatistics/England-Premier-League-2020-2021"

driver.get(url)
html = driver.execute_script('return document.body.innerHTML;') #tried inner and outerHTML
soup = bs4.BeautifulSoup(html, 'html.parser')
# 'lxml')

# %%
print(soup.prettify)
# Out:
# <bound method Tag.prettify of <body data-locale-code="en" style="">
# <script>
#
#     function hostRedirect(ctCode) {
#         if (ctCode != null) {
#             $.cookie('ct', ctCode, { expires: 30, domain: ".whoscored.com" });
#         }
#
#         var rdCountries = ["BR", "CM", "IN", "KZ", "MX", "NG", "RU", "KR", "TN", "UG", "UA", "ZM", "UZ", "VE", "VN"];
#
#         if (rdCountries.includes(ctCode)) {
#             $(location).attr('host', "1xbet.whoscored.com");
#         }
#     }
#
#     var ct = $.cookie('ct');
#     if (null == ct || ''== ct ) {
#
#         var v = $.ajaxSettings.headers["Model-last-Mode"];
#         delete $.ajaxSettings.headers["Model-last-Mode"];
#
#         $.getJSON('https://extreme-ip-lookup.com/json/?key=fnEktirYODdp1mXmsUmp', function (data) {
#             hostRedirect(data.countryCode);
#         });
#         $.ajaxSettings.headers["Model-last-Mode"] = v;
#
#     }
#     else {
#         hostRedirect(ct);
#     }
# </script>
# ...

# %%
#This returns the top of the desired table.  Below it is coe for the assists table. 
#Nothing about
summary_table = soup.find_all(class_="statistics-table-tab")
summary_table
# Out:
# [<div class="statistics-table-tab" id="stage-top-player-stats-summary">
#  <div class="statistics-table-filter" id="statistics-mini-filter-summary"></div>
#  <div id="statistics-table-summary-loading"></div>
#  <div id="statistics-table-summary"></div>
#  <div id="statistics-paging-summary"></div>
#  <div id="statistics-table-summary-column-legend"></div>
#  </div>,
#  <div class="statistics-table-tab" id="stage-top-player-stats-defensive">
#  <div class="statistics-table-filter" id="statistics-mini-filter-defensive"></div>
#  <div id="statistics-table-defensive-loading"></div>
#  <div id="statistics-table-defensive"></div>
#  <div id="statistics-paging-defensive"></div>
#  <div id="statistics-table-defensive-column-legend"></div>
#  </div>,
#  <div class="statistics-table-tab" id="stage-top-player-stats-offensive">
#  <div class="statistics-table-filter" id="statistics-mini-filter-offensive"></div>
#  <div id="statistics-table-offensive-loading"></div>
# ...

# %% [markdown]
# Below: these are tags I can see upon inspection with the information I want.  Not sure why they return empty lists

# %%
table = soup.find_all(class_="ml12-lg-2 ml12-m-3 ml12-s-4 ml12-xs-5 semi-attached-table", text=True)
table
# Out:
# []

# %%
table = soup.find_all("td", class_="col12-lg-2 col12-m-3 col12-s-4 col12-xs-5 grid-abs overflow-text")
table
# Out:
# []

# %%
pd.read_html('https://www.whoscored.com/Regions/252/Tournaments/2/Seasons/8228/Stages/18685/PlayerStatistics/England-Premier-League-2020-2021')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-30-05ce630b2cce> in <module>()
# ----> 1 pd.read_html('https://www.whoscored.com/Regions/252/Tournaments/2/Seasons/8228/Stages/18685/PlayerStatistics/England-Premier-League-2020-2021')
#
# /Users/ericroberts/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/html.py in read_html(io, match, flavor, header, index_col, skiprows, attrs, parse_dates, thousands, encoding, decimal, converters, na_values, keep_default_na, displayed_only)
#    1103         na_values=na_values,
#    1104         keep_default_na=keep_default_na,
# -> 1105         displayed_only=displayed_only,
#    1106     )
#
# /Users/ericroberts/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/html.py in _parse(flavor, io, match, attrs, encoding, displayed_only, **kwargs)
#     910             break
#     911     else:
# ...

# %%
mins_played = soup.find_all("td", class_="minsPlayed")
mins_played
# Out:
# []

# %% [markdown]
# Testing pulling a tag I can see in the soup.prettify

# %%
test_tag = soup.find_all(class_="col16-lg-1 col16-m-2 col16-s-2 col16-xs-2 clock")
test_tag
# Out:
# [<div class="col16-lg-1 col16-m-2 col16-s-2 col16-xs-2 clock" id="clock">
#  <a class="iconize iconize-icon-right ui-state-transparent-default ui-state-active rc" href="/Accounts/#timeZoneId" id="tz">
#  <span class="rc-t" id="time">15:05</span><span class="ui-icon ui-icon-circle-arrow-e"></span>
#  </a>
#  </div>]

# %% [markdown]
# when I right click on the line of code in the inspect elements window highlighting the full table i want and select copy outerhtml the below is returned.  And I think it's all the info I want but specifying those tags in beautiful soup isn't working.
#
# <div class="ml12-lg-2 ml12-m-3 ml12-s-4 ml12-xs-5 semi-attached-table"><table id="top-player-stats-summary-grid" class="grid with-centered-columns hover"><thead id="player-table-statistics-head"><tr><th class="col12-lg-2 col12-m-3 col12-s-4 col12-xs-5 grid-abs">Player</th><th class="grid-ghost-cell">Player</th> <th class="global sortable ap   " data-stat-name="Apps">Apps</th>   <th class="global sortable minsPlayed   " data-stat-name="minsPlayed">Mins</th> <th class="global sortable goal   " data-stat-name="goal">Goals</th> <th class="global sortable assistTotal   " data-stat-name="assistTotal">Assists</th> <th class="global sortable yellowCard   " data-stat-name="yellowCard">Yel</th> <th class="global sortable redCard   " data-stat-name="redCard">Red</th> <th class="global sortable shotsPerGame   " data-stat-name="shotsPerGame">SpG</th> <th class="global sortable passSuccess   " data-stat-name="passSuccess">PS%</th> <th class="global sortable aerialWonPerGame   " data-stat-name="aerialWonPerGame">AerialsWon</th> <th class="global sortable manOfTheMatch   " data-stat-name="manOfTheMatch">MotM</th><th class="global sortable rating" data-stat-name="Rating">Rating</th></tr></thead><tbody id="player-table-statistics-body"><tr class="  "><td class="col12-lg-2 col12-m-3 col12-s-4 col12-xs-5 grid-abs overflow-text"><a class="player-link" href="/Players/83532/Show/Harry-Kane"><div class="table-ranking">	1</div><span class="iconize iconize-icon-left">Harry Kane<span class="ui-icon country flg-gb-eng"></span></span></a><a href="/Teams/30/Show/England-Tottenham" class="player-meta-data"><span class="team-name">Tottenham, </span></a><span><span class="player-meta-data" style="padding-left: 3px;">27</span><span class="player-meta-data">,  AM(C),FW  </span></span></td><td class="grid-ghost-cell"><a class="player-link iconize iconize-icon-left" href="/Players/83532/Show/Harry-Kane">Harry Kane<span class="ui-icon country flg-gb-eng"></span> </a><a href="/Teams/30/Show/England-Tottenham" class="player-meta-data"><span class="team-name">Tottenham, </span></a><span class="player-meta-data">27</span><span class="player-meta-data">,  AM(C),FW  </span></td>   <td>11</td><td class="minsPlayed   ">984	</td><td class="goal   ">8	</td><td class="assistTotal   ">10	</td><td class="yellowCard   ">1	</td><td class="redCard   ">-	</td><td class="shotsPerGame   ">3.7	</td><td class="passSuccess   ">70.9	</td><td class="aerialWonPerGame   ">2.3	</td><td class="manOfTheMatch   ">6	</td><td class="rating   sorted  ">8.07</td> </tr><tr class="  alt  "><td class="col12-lg-2 col12-m-3 col12-s-4 col12-xs-5 grid-abs overflow-text"><a class="player-link" href="/Players/113069/Show/Jack-Grealish"><div class="table-ranking">	2</div><span class="iconize iconize-icon-left">Jack Grealish<span class="ui-icon country flg-gb-eng"></span></span></a><a href="/Teams/24/Show/England-Aston-Villa" class="player-meta-data"><span class="team-name">Aston Villa, </span></a><span><span class="player-meta-data" style="padding-left: 3px;">25</span><span class="player-meta-data">,  AM(CL)  </span></span></td><td class="grid-ghost-cell"><a class="player-link iconize iconize-icon-left" href="/Players/113069/Show/Jack-Grealish">Jack Grealish<span class="ui-icon country flg-gb-eng"></span> </a><a href="/Teams/24/Show/England-Aston-Villa" class="player-meta-data"><span class="team-name">Aston Villa, </span></a><span class="player-meta-data">25</span><span class="player-meta-data">,  AM(CL)  </span></td>   <td>10</td><td class="minsPlayed   ">900	</td><td class="goal   ">5	</td><td class="assistTotal   ">5	</td><td class="yellowCard   ">3	</td><td class="redCard   ">-	</td><td class="shotsPerGame   ">3	</td><td class="passSuccess   ">80.7	</td><td class="aerialWonPerGame   ">1.4	</td><td class="manOfTheMatch   ">3	</td><td class="rating   sorted  ">7.95</td> </tr><tr class="  "><td class="col12-lg-2 col12-m-3 col12-s-4 col12-xs-5 grid-abs overflow-text"><a class="player-link" href="/Players/91909/Show/Son-Heung-Min"><div class="table-ranking">	3</div><span class="iconize iconize-icon-left">Son Heung-Min<span class="ui-icon country flg-kr"></span></span></a><a href="/Teams/30/Show/England-Tottenham" class="player-meta-data"><span class="team-name">Tottenham, </span></a><span><span class="player-meta-data" style="padding-left: 3px;">28</span><span class="player-meta-data">,  M(CLR),FW  </span></span></td><td class="grid-ghost-cell"><a class="player-link iconize iconize-icon-left" href="/Players/91909/Show/Son-Heung-Min">Son Heung-Min<span class="ui-icon country flg-kr"></span> </a><a href="/Teams/30/Show/England-Tottenham" class="player-meta-data"><span class="team-name">Tottenham, </span></a><span class="player-meta-data">28</span><span class="player-meta-data">,  M(CLR),FW  </span></td>   <td>11</td><td class="minsPlayed   ">912	</td><td class="goal   ">10	</td><td class="assistTotal   ">3	</td><td class="yellowCard   ">-	</td><td class="redCard   ">-	</td><td class="shotsPerGame   ">1.9	</td><td class="passSuccess   ">82.5	</td><td class="aerialWonPerGame   ">0.6	</td><td class="manOfTheMatch   ">-	</td><td class="rating   sorted  ">7.68</td> </tr><tr class="  alt  "><td class="col12-lg-2 col12-m-3 col12-s-4 col12-xs-5 grid-abs overflow-text"><a class="player-link" href="/Players/141469/Show/Dominic-Calvert-Lewin"><div class="table-ranking">	4</div><span class="iconize iconize-icon-left">Dominic Calvert-Lewin<span class="ui-icon country flg-gb-eng"></span></span></a><a href="/Teams/31/Show/England-Everton" class="player-meta-data"><span class="team-name">Everton, </span></a><span><span class="player-meta-data" style="padding-left: 3px;">23</span><span class="player-meta-data">,  AM(L),FW  </span></span></td><td class="grid-ghost-cell"><a class="player-link iconize iconize-icon-left" href="/Players/141469/Show/Dominic-Calvert-Lewin">Dominic Calvert-Lewin<span class="ui-icon country flg-gb-eng"></span> </a><a href="/Teams/31/Show/England-Everton" class="player-meta-data"><span class="team-name">Everton, </span></a><span class="player-meta-data">23</span><span class="player-meta-data">,  AM(L),FW  </span></td>   <td>11</td><td class="minsPlayed   ">970	</td><td class="goal   ">11	</td><td class="assistTotal   ">-	</td><td class="yellowCard   ">1	</td><td class="redCard   ">-	</td><td class="shotsPerGame   ">3.3	</td><td class="passSuccess   ">74.4	</td><td class="aerialWonPerGame   ">4.6	</td><td class="manOfTheMatch   ">2	</td><td class="rating   sorted  ">7.68</td> </tr><tr class="  "><td class="col12-lg-2 col12-m-3 col12-s-4 col12-xs-5 grid-abs overflow-text"><a class="player-link" href="/Players/83683/Show/Serge-Aurier"><div class="table-ranking">	5</div><span class="iconize iconize-icon-left">Serge Aurier<span class="ui-icon country flg-ci"></span></span></a><a href="/Teams/30/Show/England-Tottenham" class="player-meta-data"><span class="team-name">Tottenham, </span></a><span><span class="player-meta-data" style="padding-left: 3px;">27</span><span class="player-meta-data">,  D(CLR),M(R)  </span></span></td><td class="grid-ghost-cell"><a class="player-link iconize iconize-icon-left" href="/Players/83683/Show/Serge-Aurier">Serge Aurier<span class="ui-icon country flg-ci"></span> </a><a href="/Teams/30/Show/England-Tottenham" class="player-meta-data"><span class="team-name">Tottenham, </span></a><span class="player-meta-data">27</span><span class="player-meta-data">,  D(CLR),M(R)  </span></td>   <td>5</td><td class="minsPlayed   ">450	</td><td class="goal   ">1	</td><td class="assistTotal   ">1	</td><td class="yellowCard   ">-	</td><td class="redCard   ">-	</td><td class="shotsPerGame   ">1	</td><td class="passSuccess   ">76.6	</td><td class="aerialWonPerGame   ">2.2	</td><td class="manOfTheMatch   ">-	</td><td class="rating   sorted  ">7.67</td> </tr><tr class="  alt  "><td class="col12-lg-2 col12-m-3 col12-s-4 col12-xs-5 grid-abs overflow-text"><a class="player-link" href="/Players/108226/Show/Mohamed-Salah"><div class="table-ranking">	6</div><span class="iconize iconize-icon-left">Mohamed Salah<span class="ui-icon country flg-eg"></span></span></a><a href="/Teams/26/Show/England-Liverpool" class="player-meta-data"><span class="team-name">Liverpool, </span></a><span><span class="player-meta-data" style="padding-left: 3px;">28</span><span class="player-meta-data">,  AM(CLR),FW  </span></span></td><td class="grid-ghost-cell"><a class="player-link iconize iconize-icon-left" href="/Players/108226/Show/Mohamed-Salah">Mohamed Salah<span class="ui-icon country flg-eg"></span> </a><a href="/Teams/26/Show/England-Liverpool" class="player-meta-data"><span class="team-name">Liverpool, </span></a><span class="player-meta-data">28</span><span class="player-meta-data">,  AM(CLR),FW  </span></td>   <td>10</td><td class="minsPlayed   ">874	</td><td class="goal   ">9	</td><td class="assistTotal   ">2	</td><td class="yellowCard   ">-	</td><td class="redCard   ">-	</td><td class="shotsPerGame   ">3.8	</td><td class="passSuccess   ">84	</td><td class="aerialWonPerGame   ">0.2	</td><td class="manOfTheMatch   ">2	</td><td class="rating   sorted  ">7.64</td> </tr><tr class="  "><td class="col12-lg-2 col12-m-3 col12-s-4 col12-xs-5 grid-abs overflow-text"><a class="player-link" href="/Players/71182/Show/James-Rodríguez"><div class="table-ranking">	7</div><span class="iconize iconize-icon-left">James Rodríguez<span class="ui-icon country flg-co"></span></span></a><a href="/Teams/31/Show/England-Everton" class="player-meta-data"><span class="team-name">Everton, </span></a><span><span class="player-meta-data" style="padding-left: 3px;">29</span><span class="player-meta-data">,  AM(CLR)  </span></span></td><td class="grid-ghost-cell"><a class="player-link iconize iconize-icon-left" href="/Players/71182/Show/James-Rodríguez">James Rodríguez<span class="ui-icon country flg-co"></span> </a><a href="/Teams/31/Show/England-Everton" class="player-meta-data"><span class="team-name">Everton, </span></a><span class="player-meta-data">29</span><span class="player-meta-data">,  AM(CLR)  </span></td>   <td>10</td><td class="minsPlayed   ">846	</td><td class="goal   ">3	</td><td class="assistTotal   ">3	</td><td class="yellowCard   ">1	</td><td class="redCard   ">-	</td><td class="shotsPerGame   ">2.2	</td><td class="passSuccess   ">83.5	</td><td class="aerialWonPerGame   ">0.4	</td><td class="manOfTheMatch   ">2	</td><td class="rating   sorted  ">7.63</td> </tr><tr class="  alt  "><td class="col12-lg-2 col12-m-3 col12-s-4 col12-xs-5 grid-abs overflow-text"><a class="player-link" href="/Players/118326/Show/Dwight-Gayle"><div class="table-ranking">	8</div><span class="iconize iconize-icon-left">Dwight Gayle<span class="ui-icon country flg-gb-eng"></span></span></a><a href="/Teams/23/Show/England-Newcastle" class="player-meta-data"><span class="team-name">Newcastle, </span></a><span><span class="player-meta-data" style="padding-left: 3px;">31</span><span class="player-meta-data">,  AM(L),FW  </span></span></td><td class="grid-ghost-cell"><a class="player-link iconize iconize-icon-left" href="/Players/118326/Show/Dwight-Gayle">Dwight Gayle<span class="ui-icon country flg-gb-eng"></span> </a><a href="/Teams/23/Show/England-Newcastle" class="player-meta-data"><span class="team-name">Newcastle, </span></a><span class="player-meta-data">31</span><span class="player-meta-data">,  AM(L),FW  </span></td>   <td>0(1)</td><td class="minsPlayed   ">21	</td><td class="goal   ">1	</td><td class="assistTotal   ">-	</td><td class="yellowCard   ">-	</td><td class="redCard   ">-	</td><td class="shotsPerGame   ">3	</td><td class="passSuccess   ">88.9	</td><td class="aerialWonPerGame   ">2	</td><td class="manOfTheMatch   ">-	</td><td class="rating   sorted  ">7.63</td> </tr><tr class="  "><td class="col12-lg-2 col12-m-3 col12-s-4 col12-xs-5 grid-abs overflow-text"><a class="player-link" href="/Players/123761/Show/Bruno-Fernandes"><div class="table-ranking">	9</div><span class="iconize iconize-icon-left">Bruno Fernandes<span class="ui-icon country flg-pt"></span></span></a><a href="/Teams/32/Show/England-Man-Utd" class="player-meta-data"><span class="team-name">Man Utd, </span></a><span><span class="player-meta-data" style="padding-left: 3px;">26</span><span class="player-meta-data">,  M(CLR)  </span></span></td><td class="grid-ghost-cell"><a class="player-link iconize iconize-icon-left" href="/Players/123761/Show/Bruno-Fernandes">Bruno Fernandes<span class="ui-icon country flg-pt"></span> </a><a href="/Teams/32/Show/England-Man-Utd" class="player-meta-data"><span class="team-name">Man Utd, </span></a><span class="player-meta-data">26</span><span class="player-meta-data">,  M(CLR)  </span></td>   <td>10(1)</td><td class="minsPlayed   ">886	</td><td class="goal   ">7	</td><td class="assistTotal   ">4	</td><td class="yellowCard   ">2	</td><td class="redCard   ">-	</td><td class="shotsPerGame   ">3.1	</td><td class="passSuccess   ">75.7	</td><td class="aerialWonPerGame   ">0.3	</td><td class="manOfTheMatch   ">2	</td><td class="rating   sorted  ">7.59</td> </tr><tr class="  alt  "><td class="col12-lg-2 col12-m-3 col12-s-4 col12-xs-5 grid-abs overflow-text"><a class="player-link" href="/Players/299272/Show/Ben-Chilwell"><div class="table-ranking">	10</div><span class="iconize iconize-icon-left">Ben Chilwell<span class="ui-icon country flg-gb-eng"></span></span></a><a href="/Teams/15/Show/England-Chelsea" class="player-meta-data"><span class="team-name">Chelsea, </span></a><span><span class="player-meta-data" style="padding-left: 3px;">23</span><span class="player-meta-data">,  D(L),M(L)  </span></span></td><td class="grid-ghost-cell"><a class="player-link iconize iconize-icon-left" href="/Players/299272/Show/Ben-Chilwell">Ben Chilwell<span class="ui-icon country flg-gb-eng"></span> </a><a href="/Teams/15/Show/England-Chelsea" class="player-meta-data"><span class="team-name">Chelsea, </span></a><span class="player-meta-data">23</span><span class="player-meta-data">,  D(L),M(L)  </span></td>   <td>8</td><td class="minsPlayed   ">712	</td><td class="goal   ">2	</td><td class="assistTotal   ">2	</td><td class="yellowCard   ">1	</td><td class="redCard   ">-	</td><td class="shotsPerGame   ">1.1	</td><td class="passSuccess   ">82.1	</td><td class="aerialWonPerGame   ">1.9	</td><td class="manOfTheMatch   ">1	</td><td class="rating   sorted  ">7.52</td> </tr></tbody></table></div>

# %%
# #Trying different selenium functions:
html2 = driver.find_element_by_tag_name("ml12-lg-2 ml12-m-3 ml12-s-4 ml12-xs-5 semi-attached-table")
html2
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-29-b064620371a1> in <module>()
#       1 # #Trying different selenium functions:
# ----> 2 html2 = driver.find_element_by_tag_name("ml12-lg-2 ml12-m-3 ml12-s-4 ml12-xs-5 semi-attached-table")
#       3 html2
#
# /Users/ericroberts/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_tag_name(self, name)
#     528             element = driver.find_element_by_tag_name('h1')
#     529         """
# --> 530         return self.find_element(by=By.TAG_NAME, value=name)
#     531
#     532     def find_elements_by_tag_name(self, name):
#
# /Users/ericroberts/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element(self, by, value)
#     976         return self.execute(Command.FIND_ELEMENT, {
# ...

# %%
#https://stackoverflow.com/questions/52647129/python-selenium-how-to-extract-outerhtml

driver.find_element_by_css_selector('div.ml12-lg-2 ml12-m-3 ml12-s-4 ml12-xs-5 semi-attached-table').get_attribute('outerHTML')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-8-6ea7e1b4dd8a> in <module>()
#       1 #https://stackoverflow.com/questions/52647129/python-selenium-how-to-extract-outerhtml
#       2
# ----> 3 driver.find_element_by_css_selector('div.ml12-lg-2 ml12-m-3 ml12-s-4 ml12-xs-5 semi-attached-table').get_attribute('outerHTML')
#
# /Users/ericroberts/anaconda3/envs/learn-env/lib/python3.6/site-packages/selenium/webdriver/remote/webdriver.py in find_element_by_css_selector(self, css_selector)
#     596             element = driver.find_element_by_css_selector('#foo')
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#     600     def find_elements_by_css_selector(self, css_selector):
#
# ...

# %%
#following along here: https://towardsdatascience.com/how-to-use-selenium-to-web-scrape-with-example-80f9b23a843a
# Again, returning empty lists.
url = "https://www.whoscored.com/Regions/252/Tournaments/2/Seasons/8228/Stages/18685/PlayerStatistics/England-Premier-League-2020-2021"

driver.get(url)
mins_played = driver.find_elements_by_xpath('//td[@class="minsPlayed   "]')
mins_played
