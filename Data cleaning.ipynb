# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Cleaning the target variable
# * Removing observations that can't be used
#     - Loans
#     - Free transfers
#     - Academy promotions
# * Converting the fee to an integer
#      - Stripping the currency symbol
#      - Converting string decimal notation to a multiplier
#      - Converting fee to integer on same scale

# %%
tf_df = pd.read_csv('data/Top_8_leagues_past_6_windows.csv')

# %%
tf_df.drop(labels="Unnamed: 0", axis=1, inplace=True)

# %%
tf_df.head()
# Out:
#             player  age nationality            position  \
# 0   Ante Palaversa   18     Croatia  Defensive Midfield
# 1       Ko Itakura   21       Japan         Centre-Back
# 2   Yangel Herrera   20   Venezuela    Central Midfield
# 3    Marlos Moreno   22    Colombia        Right Winger
# 4  Anthony Cáceres   26   Australia    Central Midfield
#
#                    selling_club previous_league est_market_value  \
# 0              HNK Hajduk Split         Croatia          £495Th.
# 1             Kawasaki Frontale           Japan          £630Th.
# 2              New York City FC   United States          £900Th.
# 3  Clube de Regatas do Flamengo          Brazil          £450Th.
# 4             Melbourne City FC       Australia          £450Th.
#
#                        fee      buying_club window  year buying_league
# 0                   £5.67m  Manchester City  s_w=w  2018           GB1
# 1                  £990Th.  Manchester City  s_w=w  2018           GB1
# 2  End of loanDec 31, 2018  Manchester City  s_w=w  2018           GB1
# 3  End of loanDec 31, 2018  Manchester City  s_w=w  2018           GB1
# 4  End of loanDec 31, 2018  Manchester City  s_w=w  2018           GB1

# %%
# Multiple players have duplicate entries e.g., Nikola Kalinic 2020, Wesley Fofana 2020, Moussa Konaté 2020
# tf_df.loc[tf_df['player']=='Nikola Kalinic',:]

# %%
tf_df.shape
# Out:
# (9666, 12)

# %%
# Not unusual for players to be transfered multiple times even in same year so only removing duplicates with the
# exact same fee, buying club and selling club in the same year.
tf_df.drop_duplicates(subset=['player','selling_club','buying_club','fee','year'], keep='first', inplace=True)

# %%
tf_df.shape
# Out:
# (9378, 12)

# %%
tf_df['fee'].value_counts()
# Out:
# free transfer              1139
# loan transfer              1088
# -                          1010
# End of loanJun 30, 2019     988
# End of loanJun 30, 2018     932
#                            ...
# £6.21m                        1
# £59Th.                        1
# End of loanJul 16, 2019       1
# £16.02m                       1
# £23.85m                       1
# Name: fee, Length: 627, dtype: int64

# %% [markdown]
# ### Counting and labeling loan deals

# %%
tf_df['loan'] = tf_df['fee'].apply(lambda x: 1 if 'loan' in x.lower() else 0)

# %%
tf_df['loan'].value_counts()
# Out:
# 1    5056
# 0    4322
# Name: loan, dtype: int64

# %% [markdown]
# 5056 loan deals.  Not unexpected.

# %% [markdown]
# ### Counting and labeling free transfers

# %%
tf_df['free'] = tf_df['fee'].apply(lambda x: 1 if 'free' in x.lower() else 0)

# %%
tf_df['free'].value_counts()
# Out:
# 0    8239
# 1    1139
# Name: free, dtype: int64

# %%
#Want to see if there are any other types of free transfers
# pd.options.display.max_rows = 1200
tf_df.loc[tf_df['free'] == 1, 'fee']
# Out:
# 20      free transfer
# 33      free transfer
# 46      free transfer
# 86      free transfer
# 131     free transfer
#             ...
# 9636    free transfer
# 9637    free transfer
# 9638    free transfer
# 9652    free transfer
# 9653    free transfer
# Name: fee, Length: 1139, dtype: object

# %% [markdown]
# Free transfers happen when a contract is run down; contract length is an important determinant of transfer fee but I don't have that information.  Here, while it would be important for clubs to know how much time is left on a contract (as they may be able to use that as leverage to get a better deal) I'll use the model to bench mark the going market rate for a player of that profile.

# %% [markdown]
# ### In the fee value count: 1010 "-"
# ### These appear to be internal promotions, e.g., from the U23 team. Investigating and labeling here

# %%
# pd.options.display.max_rows = 30
tf_df.loc[tf_df['fee'] == "-", ['player','fee','selling_club','buying_club']]
# Out:
#                    player fee          selling_club       buying_club
# 16     Callum Hudson-Odoi   -        Chelsea FC U23        Chelsea FC
# 19          Eddie Nketiah   -        Arsenal FC U23        Arsenal FC
# 29         Sean Longstaff   -  Newcastle United U23  Newcastle United
# 42            Kyle Taylor   -   AFC Bournemouth U21   AFC Bournemouth
# 44            Samir Nasri   -      Disqualification   West Ham United
# ...                   ...  ..                   ...               ...
# 9591       Andrey Bokovoy   -           FK Sochi II          FC Sochi
# 9603         Arsen Adamov   -      Akhmat Grozny II     Akhmat Grozny
# 9621  Vladimir Kabakhidze   -          FK Tambov II       PFK  Tambov
# 9639         Nikita Repin   -     Rotor 2 Volgograd   Rotor Volgograd
# 9646     Nikita Muromskiy   -     Rotor 2 Volgograd   Rotor Volgograd
#
# [1010 rows x 4 columns]

# %% [markdown]
# The fee "-" are internal promotions or picking up players without a club for free.  Will not be used in our model

# %%
# removing loans, free transfers, academy promotions
tfdf2 = tf_df.loc[(tf_df['fee'] != "-")&(tf_df['loan'] == 0)&(tf_df['free'] == 0), :]

# %%
tfdf2.head()
# Out:
#                player  age    nationality            position  \
# 0      Ante Palaversa   18        Croatia  Defensive Midfield
# 1          Ko Itakura   21          Japan         Centre-Back
# 10  Christian Pulisic   20  United States         Left Winger
# 27     Miguel Almirón   24       Paraguay  Attacking Midfield
# 38    Dominic Solanke   21        England      Centre-Forward
#
#          selling_club previous_league est_market_value      fee  \
# 0    HNK Hajduk Split         Croatia          £495Th.   £5.67m
# 1   Kawasaki Frontale           Japan          £630Th.  £990Th.
# 10  Borussia Dortmund         Germany          £45.00m  £57.60m
# 27  Atlanta United FC   United States          £13.50m  £21.60m
# 38       Liverpool FC         England           £9.00m  £19.08m
#
#          buying_club window  year buying_league  loan  free
# 0    Manchester City  s_w=w  2018           GB1     0     0
# 1    Manchester City  s_w=w  2018           GB1     0     0
# 10        Chelsea FC  s_w=w  2018           GB1     0     0
# 27  Newcastle United  s_w=w  2018           GB1     0     0
# 38   AFC Bournemouth  s_w=w  2018           GB1     0     0

# %%
tfdf2.shape
# Out:
# (2173, 14)

# %%
# pd.options.display.max_rows = 20
# tfdf2['previous_league'].value_counts()
# Top 6 countries:
# Italy                   299
# France                  258
# England                 225
# Spain                   222
# Portugal                175
# Germany                 172

# %% [markdown]
# Evaluating the value counts of previous league - there are only 1176 observations where a player was bought from a league in the Big 5.  Currently only have detailed statistical profile of players from the top 5 leagues.  Looked to pull in more years and data from more leagues but fbref doesn't have detailed stats for leagues outside the top 5 (except for MLS) or for more than 3 years.  Will have to proceed with what I have understanding this is a bit reduced in scope by virture of data.

# %%
#Creating an indicator for bought from a top five league to faciliate merging with statistical data
tfdf2['buying_top_5'] = tfdf2['previous_league'].map(lambda x: 1 if x in ["Italy",'France','England','Spain','Germany'] else 0)
# Out:
# /Users/ericroberts/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
pd.options.mode.chained_assignment = None  # default='warn'

# %%
tfdf2['buying_top_5'].value_counts()
# Out:
# 1    1176
# 0     997
# Name: buying_top_5, dtype: int64

# %%
tfdf3 = tfdf2.loc[(tfdf2['buying_top_5'] == 1), :]

# %%
tfdf3.shape
# Out:
# (1176, 15)

# %% [markdown]
# ### Turning fee column into an integer

# %%
tfdf3['fee'].value_counts()
# Out:
# ?          69
# £1.80m     65
# £2.70m     45
# £900Th.    42
# £4.50m     41
#            ..
# £324Th.     1
# £3.33m      1
# £18.81m     1
# £90         1
# £23.85m     1
# Name: fee, Length: 265, dtype: int64

# %%
filt =  tfdf3['fee']=='?'
tfdf3.drop(index=tfdf3[filt].index, inplace=True)

# %%
tfdf3['fee'].value_counts()
# Out:
# £1.80m     65
# £2.70m     45
# £900Th.    42
# £3.60m     41
# £4.50m     41
#            ..
# £324Th.     1
# £3.33m      1
# £18.81m     1
# £90         1
# £23.85m     1
# Name: fee, Length: 264, dtype: int64

# %%
tfdf3['currency'] = tfdf3['fee'].apply(lambda x: x[0])

# %%
tfdf3['currency'].value_counts()
# Out:
# £    1107
# Name: currency, dtype: int64

# %%
tfdf3['multiplier'] = tfdf3['fee'].str.extract(r'([a-zA-Z]+)')

# %%
tfdf3['multiplier'].value_counts()
# Out:
# m     936
# Th    168
# Name: multiplier, dtype: int64

# %%
tfdf3.isna().sum()
# Out:
# player              0
# age                 0
# nationality         0
# position            0
# selling_club        0
# previous_league     0
# est_market_value    0
# fee                 0
# buying_club         0
# window              0
# year                0
# buying_league       0
# loan                0
# free                0
# buying_top_5        0
# currency            0
# multiplier          3
# dtype: int64

# %%
# If there was no multiplier specified assuming it is in the specified units
tfdf3.fillna(value=1, inplace=True)

# %%
tfdf3['multiplier'].value_counts()
# Out:
# m     936
# Th    168
# 1       3
# Name: multiplier, dtype: int64

# %%
tfdf3['fee_numerical'] = tfdf3['fee'].str.extract(r'([0-9]+\.?[0-9]+)')

# %%
# convert numeric columns to appropiate dypes
tfdf3 = tfdf3.astype({'fee_numerical':'float'})

# %%
tfdf3.loc[tfdf3['multiplier'] == 'm', 'mult_num'] = 1000000
tfdf3.loc[tfdf3['multiplier'] == 'Th', 'mult_num'] = 1000
tfdf3.loc[tfdf3['multiplier'] == 1, 'mult_num'] = 1

# %%
tfdf3['fee_final'] = tfdf3['fee_numerical']*tfdf3['mult_num']

# %%
tfdf3['fee_final']
# Out:
# 10      57600000.0
# 38      19080000.0
# 39      12240000.0
# 57       1530000.0
# 65      18900000.0
#            ...
# 9232     2700000.0
# 9320    18000000.0
# 9321     5400000.0
# 9455    10800000.0
# 9466     4950000.0
# Name: fee_final, Length: 1107, dtype: float64

# %%
# tfdf3.head()

# %% [markdown]
# ## Creating variables to index on for merging:
# Need to assess and clean variables for this purpose in both dataframes:
# * Player name
# * Year of stats/year of transfer - using a one year lag (e.g., purchase in 2018 will be modeled with 2017 stats.
#     - Note: the winter transfer window is labeled a year early (winter 2018 was the Jan 2019 window). Therefore use the 2017/2018 stats to predict winter/summer 2018 prices
# * Columns with same information but different format:
#     * club name in stats/selling club in transfers
#     * nationality
#     * previous_league/league
#     * position

# %%
statsdf = pd.read_csv('data/Player_stats_top_5_leagues_2017_to_2020.csv')

# %%
# tfdf3.head()

# %%
# tfdf3['player'].value_counts()

# %%
# tfdf3.loc[tfdf3['player']=='Enric Gallego',:]

# %%
# statsdf.loc[statsdf['players']=='Enric Gallego',:]

# %%
statsdf['xa_net']
# Out:
# 0       1.6
# 1      -0.5
# 2      -0.4
# 3      -0.2
# 4      -0.1
#        ...
# 8072   -0.7
# 8073   -0.9
# 8074    0.0
# 8075   -0.2
# 8076    0.7
# Name: xa_net, Length: 8077, dtype: float64

# %%
statsdf.head()
# Out:
#          players nationality            team position   age  birth_year  \
# 0  David Abraham      ar ARG  Eint Frankfurt       DF  31.0      1986.0
# 1   Amir Abrashi      al ALB        Freiburg       MF  27.0      1990.0
# 2     René Adler      de GER        Mainz 05       GK  32.0      1985.0
# 3         Ailton      br BRA       Stuttgart    DF,FW  22.0      1995.0
# 4  Manuel Akanji      ch SUI        Dortmund       DF  22.0      1995.0
#
#    games  games_start   mins  goals  ...  passes_received_pct  miscontrols  \
# 0     27           27  2,302      0  ...                 98.6          5.0
# 1     12           11    850      0  ...                 86.5          9.0
# 2     14           14  1,260      0  ...                100.0          0.0
# 3      5            1    108      0  ...                 86.8          3.0
# 4     11           10    904      0  ...                 98.1          5.0
#
#    dispossessed  passes_left_foot  passes_right_foot  aerials_won  \
# 0           6.0             208.0              923.0         62.0
# 1          14.0              18.0              272.0         21.0
# 2           0.0              39.0              284.0          0.0
# 3           0.0              46.0                3.0          2.0
# 4           3.0             142.0              394.0         17.0
#
#    aerials_lost  aerials_won_pct       year      league
# 0          26.0             70.5  2017-2018  Bundesliga
# 1          19.0             52.5  2017-2018  Bundesliga
# 2           1.0              0.0  2017-2018  Bundesliga
# 3           3.0             40.0  2017-2018  Bundesliga
# 4          17.0             50.0  2017-2018  Bundesliga
#
# [5 rows x 136 columns]

# %% [markdown]
# ## ASSESSING MISSINGNESS

# %%
tfdf3.isna().sum()
# Out:
# player              0
# age                 0
# nationality         0
# position            0
# selling_club        0
# previous_league     0
# est_market_value    0
# fee                 0
# buying_club         0
# window              0
# year                0
# buying_league       0
# loan                0
# free                0
# buying_top_5        0
# currency            0
# multiplier          0
# fee_numerical       0
# mult_num            0
# fee_final           0
# dtype: int64

# %%
pd.options.display.max_rows = 140
statsdf.isna().sum()
# Out:
# players                          0
# nationality                      1
# team                             0
# position                         1
# age                              7
# birth_year                       7
# games                            0
# games_start                      0
# mins                             0
# goals                            0
# assists                          0
# pens_successful                  0
# pens_attempts                    0
# yellow_cards                     0
# red_cards                        0
# goals_per_90                     0
# assists_per_90                   0
# goals_and_assists_per_90         0
# goals_pk_per_90                  0
# goals_assists_pk_per_90          0
# xg                              10
# npxp                            10
# xa                              10
# xg_per90                        20
# xa_per90                        20
# xg_xa_per90_list                20
# npxg_per90_list                 20
# npxg_xa_per90                   20
# full_90s_played                  0
# goals.1                          0
# shots_total                      7
# shots_on_target                  0
# shots_on_target_pct           1405
# shots_total_per90                7
# shots_on_target_per90            0
# goals_per_shot                1405
# goals_per_shot_on_target      2412
# avg_shot_dist                 1407
# pens_successful.1                0
# pens_attempts.1                  0
# xg.1                            10
# npxg                            10
# npxg_per_shot                 1406
# xg_net                          10
# npxg_net                        10
# full_90s_played.1                0
# passes_completed                10
# passes_attempted                10
# pass_percent                    52
# passes_total_dist               10
# passes_prog_dist                10
# passes_completed_short          10
# passes_attempted_short          10
# pass_percent_short             129
# passes_completed_medium         10
# passes_attempted_medium         10
# pass_percent_medium            133
# passes_completed_long           10
# passes_attempted_long           10
# pass_percent_long              328
# assists.1                        0
# xa.1                            10
# xa_net                          10
# assisted_shots                  10
# passes_into_final_third         10
# passes_into_penalty_area        10
# crosses_into_penalty_area       10
# progressive_passes              51
# sca                             10
# sca_per90                       20
# sca_passes_live                 10
# sca_passes_dead                 10
# sca_dribbles                    10
# sca_shots                       10
# sca_fouled                      10
# sca_defense                     10
# gca                             10
# gca_per90                       20
# gca_passes_live                 10
# gca_passes_dead                 10
# gca_dribbles                    10
# gca_shots                       10
# gca_fouled                      10
# gca_defense                     10
# gca_og_for                      10
# tackles                         10
# tackles_won                      7
# tackles_def_3rd                 10
# tackles_mid_3rd                 10
# tackles_att_3rd                 10
# dribble_tackles                 10
# dribble_vs                      10
# dribble_tackles_pct            857
# dribbled_past                   10
# pressures                       10
# pressure_regains                10
# pressure_regain_pct            364
# pressures_def_3rd               10
# pressures_mid_3rd               10
# pressures_att_3rd               10
# blocks                          10
# blocked_shots                   10
# blocked_shots_saves             10
# blocked_passes                  10
# interceptions                    7
# tackles_interceptions            0
# clearances                      10
# errors                          10
# full_90s_played.2                0
# touches                         10
# touches_def_pen_area            10
# touches_def_3rd                 10
# touches_mid_3rd                 10
# touches_att_3rd                 10
# touches_att_pen_area            10
# touches_live_ball               10
# dribbles_completed              10
# dribbles                        10
# dribbles_completed_pct        1173
# players_dribbled_past           10
# nutmegs                         10
# carries                         10
# carry_distance                  10
# carry_progressive_distance      10
# pass_targets                    10
# passes_received                 10
# passes_received_pct             43
# miscontrols                     10
# dispossessed                    10
# passes_left_foot                10
# passes_right_foot               10
# aerials_won                     10
# aerials_lost                    10
# aerials_won_pct               1021
# year                             0
# league                           0
# dtype: int64

# %% [markdown]
# * variables to use fillna:
#     - progressive_passes

# %%
#Following variables are missing hundreds of observations, are duplicates between scraped pages or will need to 
#recalculated after combining performance of one player for multiple teams.
# Dropping columns
statsdf.drop(labels=['goals_per_90', 'assists_per_90', 'goals_and_assists_per_90', 'goals_pk_per_90', 
                     'goals_assists_pk_per_90', 'xg_per90', 'xa_per90', 'xg_xa_per90_list', 'npxg_per90_list', 
                     'npxg_xa_per90', 'shots_total_per90', 'shots_on_target_per90',
                     'aerials_won_pct', 'shots_on_target_pct','goals_per_shot','goals_per_shot_on_target',
                    'avg_shot_dist','npxg_per_shot','pass_percent','pass_percent_short','pass_percent_medium',
                    'pass_percent_long','dribble_tackles_pct','pressure_regain_pct','dribbles_completed_pct', 
                    'passes_received_pct','goals.1','pens_successful.1','pens_attempts.1','xg.1','npxg_per_shot',
                    'xg_net','npxg_net','full_90s_played.1','assists.1','xa.1','full_90s_played.2','sca_per90',
                     'gca_per90'], axis=1, inplace=True)

# %%
#Assessing remaining missing variables 
pd.options.display.max_rows = 140
statsdf.isna().sum()
# Out:
# players                        0
# nationality                    1
# team                           0
# position                       1
# age                            7
# birth_year                     7
# games                          0
# games_start                    0
# mins                           0
# goals                          0
# assists                        0
# pens_successful                0
# pens_attempts                  0
# yellow_cards                   0
# red_cards                      0
# xg                            10
# npxp                          10
# xa                            10
# full_90s_played                0
# shots_total                    7
# shots_on_target                0
# npxg                          10
# passes_completed              10
# passes_attempted              10
# passes_total_dist             10
# passes_prog_dist              10
# passes_completed_short        10
# passes_attempted_short        10
# passes_completed_medium       10
# passes_attempted_medium       10
# passes_completed_long         10
# passes_attempted_long         10
# xa_net                        10
# assisted_shots                10
# passes_into_final_third       10
# passes_into_penalty_area      10
# crosses_into_penalty_area     10
# progressive_passes            51
# sca                           10
# sca_passes_live               10
# sca_passes_dead               10
# sca_dribbles                  10
# sca_shots                     10
# sca_fouled                    10
# sca_defense                   10
# gca                           10
# gca_passes_live               10
# gca_passes_dead               10
# gca_dribbles                  10
# gca_shots                     10
# gca_fouled                    10
# gca_defense                   10
# gca_og_for                    10
# tackles                       10
# tackles_won                    7
# tackles_def_3rd               10
# tackles_mid_3rd               10
# tackles_att_3rd               10
# dribble_tackles               10
# dribble_vs                    10
# dribbled_past                 10
# pressures                     10
# pressure_regains              10
# pressures_def_3rd             10
# pressures_mid_3rd             10
# pressures_att_3rd             10
# blocks                        10
# blocked_shots                 10
# blocked_shots_saves           10
# blocked_passes                10
# interceptions                  7
# tackles_interceptions          0
# clearances                    10
# errors                        10
# touches                       10
# touches_def_pen_area          10
# touches_def_3rd               10
# touches_mid_3rd               10
# touches_att_3rd               10
# touches_att_pen_area          10
# touches_live_ball             10
# dribbles_completed            10
# dribbles                      10
# players_dribbled_past         10
# nutmegs                       10
# carries                       10
# carry_distance                10
# carry_progressive_distance    10
# pass_targets                  10
# passes_received               10
# miscontrols                   10
# dispossessed                  10
# passes_left_foot              10
# passes_right_foot             10
# aerials_won                   10
# aerials_lost                  10
# year                           0
# league                         0
# dtype: int64

# %%
statsdf2 = statsdf.fillna(value='?')

# %%
# Lots of variables are missing 10 or 20 observations.  Guessing these are all on the same player,
# likely with few appearances and therefore no statistics to report.  Confirming here.
pd.options.display.max_columns = 116
statsdf2.loc[statsdf2['passes_completed'] == '?',:]
# Out:
#                 players nationality           team position age birth_year  \
# 1821      Aiden O'Neill      au AUS        Burnley       MF  19       1998
# 3836  Christian Kouakou      ci CIV           Caen       FW  27       1991
# 4505    Ahmad Ngouyamsa      cm CMR          Dijon       DF  18       2000
# 4774  Christian Rutjens           ?      Benevento        ?   ?          ?
# 4832   Emanuele Torrasi      it ITA          Milan       MF  18       1999
# 5785     Álex Centelles      es ESP        Udinese       DF  20       1997
# 6431     Sergio Arribas      es ESP        Leganés       FW  22       1995
# 6760          Álex Mula      es ESP         Málaga    MF,FW  21       1996
# 6767  Fahad Al-Muwallad      sa KSA        Levante    FW,MF  20       1996
# 6948   Asier Villalibre      es ESP  Athletic Club       FW  19       1997
#
#       games  games_start mins  goals  assists  pens_successful  pens_attempts  \
# 1821      1            0    1      0        0                0              0
# 3836      1            0   13      0        0                0              0
# 4505      1            0   55      0        0                0              0
# 4774      1            0    1      0        0                0              0
# 4832      1            0    6      0        0                0              0
# 5785      8            6  583      0        0                0              0
# 6431      1            0   24      0        0                0              0
# 6760     11            7  560      0        0                0              0
# 6767      2            0   29      0        0                0              0
# 6948      1            1   90      0        0                0              0
#
#       yellow_cards  red_cards xg npxp xa  full_90s_played shots_total  \
# 1821             0          0  ?    ?  ?              0.0           ?
# 3836             0          0  ?    ?  ?              0.1           0
# 4505             1          0  ?    ?  ?              0.6           0
# 4774             0          0  ?    ?  ?              0.0           ?
# 4832             0          0  ?    ?  ?              0.1           ?
# 5785             4          0  ?    ?  ?              6.5           4
# 6431             0          0  ?    ?  ?              0.3           ?
# 6760             1          0  ?    ?  ?              6.2           ?
# 6767             0          0  ?    ?  ?              0.3           ?
# 6948             0          0  ?    ?  ?              1.0           ?
#
#       shots_on_target npxg passes_completed passes_attempted  \
# 1821                0    ?                ?                ?
# 3836                0    ?                ?                ?
# 4505                0    ?                ?                ?
# 4774                0    ?                ?                ?
# 4832                0    ?                ?                ?
# 5785                0    ?                ?                ?
# 6431                0    ?                ?                ?
# 6760                6    ?                ?                ?
# 6767                0    ?                ?                ?
# 6948                0    ?                ?                ?
#
#      passes_total_dist passes_prog_dist passes_completed_short  \
# 1821                 ?                ?                      ?
# 3836                 ?                ?                      ?
# 4505                 ?                ?                      ?
# 4774                 ?                ?                      ?
# 4832                 ?                ?                      ?
# 5785                 ?                ?                      ?
# 6431                 ?                ?                      ?
# 6760                 ?                ?                      ?
# 6767                 ?                ?                      ?
# 6948                 ?                ?                      ?
#
#      passes_attempted_short passes_completed_medium passes_attempted_medium  \
# 1821                      ?                       ?                       ?
# 3836                      ?                       ?                       ?
# 4505                      ?                       ?                       ?
# 4774                      ?                       ?                       ?
# 4832                      ?                       ?                       ?
# 5785                      ?                       ?                       ?
# 6431                      ?                       ?                       ?
# 6760                      ?                       ?                       ?
# 6767                      ?                       ?                       ?
# 6948                      ?                       ?                       ?
#
#      passes_completed_long passes_attempted_long xa_net assisted_shots  \
# 1821                     ?                     ?      ?              ?
# 3836                     ?                     ?      ?              ?
# 4505                     ?                     ?      ?              ?
# 4774                     ?                     ?      ?              ?
# 4832                     ?                     ?      ?              ?
# 5785                     ?                     ?      ?              ?
# 6431                     ?                     ?      ?              ?
# 6760                     ?                     ?      ?              ?
# 6767                     ?                     ?      ?              ?
# 6948                     ?                     ?      ?              ?
#
#      passes_into_final_third passes_into_penalty_area  \
# 1821                       ?                        ?
# 3836                       ?                        ?
# 4505                       ?                        ?
# 4774                       ?                        ?
# 4832                       ?                        ?
# 5785                       ?                        ?
# 6431                       ?                        ?
# 6760                       ?                        ?
# 6767                       ?                        ?
# 6948                       ?                        ?
#
#      crosses_into_penalty_area progressive_passes sca sca_passes_live  \
# 1821                         ?                  ?   ?               ?
# 3836                         ?                  ?   ?               ?
# 4505                         ?                  ?   ?               ?
# 4774                         ?                  ?   ?               ?
# 4832                         ?                  ?   ?               ?
# 5785                         ?                  ?   ?               ?
# 6431                         ?                  ?   ?               ?
# 6760                         ?                  ?   ?               ?
# 6767                         ?                  ?   ?               ?
# 6948                         ?                  ?   ?               ?
#
#      sca_passes_dead sca_dribbles sca_shots sca_fouled sca_defense gca  \
# 1821               ?            ?         ?          ?           ?   ?
# 3836               ?            ?         ?          ?           ?   ?
# 4505               ?            ?         ?          ?           ?   ?
# 4774               ?            ?         ?          ?           ?   ?
# 4832               ?            ?         ?          ?           ?   ?
# 5785               ?            ?         ?          ?           ?   ?
# 6431               ?            ?         ?          ?           ?   ?
# 6760               ?            ?         ?          ?           ?   ?
# 6767               ?            ?         ?          ?           ?   ?
# 6948               ?            ?         ?          ?           ?   ?
#
#      gca_passes_live gca_passes_dead gca_dribbles gca_shots gca_fouled  \
# 1821               ?               ?            ?         ?          ?
# 3836               ?               ?            ?         ?          ?
# 4505               ?               ?            ?         ?          ?
# 4774               ?               ?            ?         ?          ?
# 4832               ?               ?            ?         ?          ?
# 5785               ?               ?            ?         ?          ?
# 6431               ?               ?            ?         ?          ?
# 6760               ?               ?            ?         ?          ?
# 6767               ?               ?            ?         ?          ?
# 6948               ?               ?            ?         ?          ?
#
#      gca_defense gca_og_for tackles tackles_won tackles_def_3rd  \
# 1821           ?          ?       ?           ?               ?
# 3836           ?          ?       ?           0               ?
# 4505           ?          ?       ?           0               ?
# 4774           ?          ?       ?           ?               ?
# 4832           ?          ?       ?           ?               ?
# 5785           ?          ?       ?           7               ?
# 6431           ?          ?       ?           ?               ?
# 6760           ?          ?       ?           ?               ?
# 6767           ?          ?       ?           ?               ?
# 6948           ?          ?       ?           ?               ?
#
#      tackles_mid_3rd tackles_att_3rd dribble_tackles dribble_vs dribbled_past  \
# 1821               ?               ?               ?          ?             ?
# 3836               ?               ?               ?          ?             ?
# 4505               ?               ?               ?          ?             ?
# 4774               ?               ?               ?          ?             ?
# 4832               ?               ?               ?          ?             ?
# 5785               ?               ?               ?          ?             ?
# 6431               ?               ?               ?          ?             ?
# 6760               ?               ?               ?          ?             ?
# 6767               ?               ?               ?          ?             ?
# 6948               ?               ?               ?          ?             ?
#
#      pressures pressure_regains pressures_def_3rd pressures_mid_3rd  \
# 1821         ?                ?                 ?                 ?
# 3836         ?                ?                 ?                 ?
# 4505         ?                ?                 ?                 ?
# 4774         ?                ?                 ?                 ?
# 4832         ?                ?                 ?                 ?
# 5785         ?                ?                 ?                 ?
# 6431         ?                ?                 ?                 ?
# 6760         ?                ?                 ?                 ?
# 6767         ?                ?                 ?                 ?
# 6948         ?                ?                 ?                 ?
#
#      pressures_att_3rd blocks blocked_shots blocked_shots_saves  \
# 1821                 ?      ?             ?                   ?
# 3836                 ?      ?             ?                   ?
# 4505                 ?      ?             ?                   ?
# 4774                 ?      ?             ?                   ?
# 4832                 ?      ?             ?                   ?
# 5785                 ?      ?             ?                   ?
# 6431                 ?      ?             ?                   ?
# 6760                 ?      ?             ?                   ?
# 6767                 ?      ?             ?                   ?
# 6948                 ?      ?             ?                   ?
#
#      blocked_passes interceptions  tackles_interceptions clearances errors  \
# 1821              ?             ?                      0          ?      ?
# 3836              ?             0                      0          ?      ?
# 4505              ?             1                      0          ?      ?
# 4774              ?             ?                      0          ?      ?
# 4832              ?             ?                      0          ?      ?
# 5785              ?            13                      0          ?      ?
# 6431              ?             ?                      0          ?      ?
# 6760              ?             ?                      0          ?      ?
# 6767              ?             ?                      0          ?      ?
# 6948              ?             ?                      0          ?      ?
#
#      touches touches_def_pen_area touches_def_3rd touches_mid_3rd  \
# 1821       ?                    ?               ?               ?
# 3836       ?                    ?               ?               ?
# 4505       ?                    ?               ?               ?
# 4774       ?                    ?               ?               ?
# 4832       ?                    ?               ?               ?
# 5785       ?                    ?               ?               ?
# 6431       ?                    ?               ?               ?
# 6760       ?                    ?               ?               ?
# 6767       ?                    ?               ?               ?
# 6948       ?                    ?               ?               ?
#
#      touches_att_3rd touches_att_pen_area touches_live_ball  \
# 1821               ?                    ?                 ?
# 3836               ?                    ?                 ?
# 4505               ?                    ?                 ?
# 4774               ?                    ?                 ?
# 4832               ?                    ?                 ?
# 5785               ?                    ?                 ?
# 6431               ?                    ?                 ?
# 6760               ?                    ?                 ?
# 6767               ?                    ?                 ?
# 6948               ?                    ?                 ?
#
#      dribbles_completed dribbles players_dribbled_past nutmegs carries  \
# 1821                  ?        ?                     ?       ?       ?
# 3836                  ?        ?                     ?       ?       ?
# 4505                  ?        ?                     ?       ?       ?
# 4774                  ?        ?                     ?       ?       ?
# 4832                  ?        ?                     ?       ?       ?
# 5785                  ?        ?                     ?       ?       ?
# 6431                  ?        ?                     ?       ?       ?
# 6760                  ?        ?                     ?       ?       ?
# 6767                  ?        ?                     ?       ?       ?
# 6948                  ?        ?                     ?       ?       ?
#
#      carry_distance carry_progressive_distance pass_targets passes_received  \
# 1821              ?                          ?            ?               ?
# 3836              ?                          ?            ?               ?
# 4505              ?                          ?            ?               ?
# 4774              ?                          ?            ?               ?
# 4832              ?                          ?            ?               ?
# 5785              ?                          ?            ?               ?
# 6431              ?                          ?            ?               ?
# 6760              ?                          ?            ?               ?
# 6767              ?                          ?            ?               ?
# 6948              ?                          ?            ?               ?
#
#      miscontrols dispossessed passes_left_foot passes_right_foot aerials_won  \
# 1821           ?            ?                ?                 ?           ?
# 3836           ?            ?                ?                 ?           ?
# 4505           ?            ?                ?                 ?           ?
# 4774           ?            ?                ?                 ?           ?
# 4832           ?            ?                ?                 ?           ?
# 5785           ?            ?                ?                 ?           ?
# 6431           ?            ?                ?                 ?           ?
# 6760           ?            ?                ?                 ?           ?
# 6767           ?            ?                ?                 ?           ?
# 6948           ?            ?                ?                 ?           ?
#
#      aerials_lost       year          league
# 1821            ?  2017-2018  Premier-League
# 3836            ?  2018-2019         Ligue-1
# 4505            ?  2019-2020         Ligue-1
# 4774            ?  2017-2018         Serie-A
# 4832            ?  2017-2018         Serie-A
# 5785            ?  2018-2019         Serie-A
# 6431            ?  2017-2018         La-Liga
# 6760            ?  2017-2018         La-Liga
# 6767            ?  2017-2018         La-Liga
# 6948            ?  2017-2018         La-Liga

# %%
#Confirmed - of the players with missing values 7 have 1 appearance, one 2, one 8 and one 11 (the latter two 
#greater than 6 full 90's) going to zero fill
statsdf.fillna(value=0, inplace=True)

# %%
#Not sure why but Christian Rutjens (index=4774 has no information)
statsdf.drop(index=4774, inplace=True)

# %%
statsdf.isna().sum()
# Out:
# players                       0
# nationality                   0
# team                          0
# position                      0
# age                           0
# birth_year                    0
# games                         0
# games_start                   0
# mins                          0
# goals                         0
# assists                       0
# pens_successful               0
# pens_attempts                 0
# yellow_cards                  0
# red_cards                     0
# xg                            0
# npxp                          0
# xa                            0
# full_90s_played               0
# shots_total                   0
# shots_on_target               0
# npxg                          0
# passes_completed              0
# passes_attempted              0
# passes_total_dist             0
# passes_prog_dist              0
# passes_completed_short        0
# passes_attempted_short        0
# passes_completed_medium       0
# passes_attempted_medium       0
# passes_completed_long         0
# passes_attempted_long         0
# xa_net                        0
# assisted_shots                0
# passes_into_final_third       0
# passes_into_penalty_area      0
# crosses_into_penalty_area     0
# progressive_passes            0
# sca                           0
# sca_passes_live               0
# sca_passes_dead               0
# sca_dribbles                  0
# sca_shots                     0
# sca_fouled                    0
# sca_defense                   0
# gca                           0
# gca_passes_live               0
# gca_passes_dead               0
# gca_dribbles                  0
# gca_shots                     0
# gca_fouled                    0
# gca_defense                   0
# gca_og_for                    0
# tackles                       0
# tackles_won                   0
# tackles_def_3rd               0
# tackles_mid_3rd               0
# tackles_att_3rd               0
# dribble_tackles               0
# dribble_vs                    0
# dribbled_past                 0
# pressures                     0
# pressure_regains              0
# pressures_def_3rd             0
# pressures_mid_3rd             0
# pressures_att_3rd             0
# blocks                        0
# blocked_shots                 0
# blocked_shots_saves           0
# blocked_passes                0
# interceptions                 0
# tackles_interceptions         0
# clearances                    0
# errors                        0
# touches                       0
# touches_def_pen_area          0
# touches_def_3rd               0
# touches_mid_3rd               0
# touches_att_3rd               0
# touches_att_pen_area          0
# touches_live_ball             0
# dribbles_completed            0
# dribbles                      0
# players_dribbled_past         0
# nutmegs                       0
# carries                       0
# carry_distance                0
# carry_progressive_distance    0
# pass_targets                  0
# passes_received               0
# miscontrols                   0
# dispossessed                  0
# passes_left_foot              0
# passes_right_foot             0
# aerials_won                   0
# aerials_lost                  0
# year                          0
# league                        0
# dtype: int64

# %% [markdown]
# ### Converting mins to a numeric variable

# %%
statsdf['mins_num'] = statsdf['mins'].map(lambda x: x.replace(",",""))

# %%
#convert to int
statsdf = statsdf.astype({'mins_num':'int'})

# %%
statsdf['mins_num'].describe()
# Out:
# count    8076.000000
# mean     1315.177935
# std       986.559807
# min         1.000000
# 25%       393.000000
# 50%      1197.500000
# 75%      2117.000000
# max      3420.000000
# Name: mins_num, dtype: float64

# %% [markdown]
# ### Years
# * Year of stats/year of transfer - using a one year lag (e.g., purchase in 2018 will be modeled with 2017 stats.
#     - Note: the winter transfer window is labeled a year early (winter 2018 was the Jan 2019 window). Therefore use the 2017/2018 stats to predict winter/summer 2018 prices

# %%
print(tfdf3['year'].value_counts())
print(tfdf3['window'].value_counts())
print(statsdf['year'].value_counts())
# Out:
# 2019    435
# 2018    401
# 2020    271
# Name: year, dtype: int64
# s_w=s    976
# s_w=w    131
# Name: window, dtype: int64
# 2019-2020    2732
# 2017-2018    2686
# 2018-2019    2658
# Name: year, dtype: int64

# %%
# tfdf3.head(20)

# %%
tfdf3['index_year'] = tfdf3['year']

# %%
#renaming year as transfer year so that after merging the column is perserved 
#and interpretable
tfdf3.rename(columns={'year':'transfer_year'}, inplace=True)

# %%
#Select the first 4 digits (the first year) for the stats years
statsdf['index_year'] = statsdf['year'].apply(lambda x: x[0:4])

# %%
#convert to int
statsdf = statsdf.astype({'index_year':'int'})

# %%
#Adding 1 to faciliate matching of the lag
#index_year will now match up the transfer to the performance stats lagged by one year
statsdf['index_year'] = statsdf['index_year']+1

# %%
#renaming year as stats_year so that after merging the column is perserved 
#and interpretable
statsdf.rename(columns={'year':'stats_year'}, inplace=True)

# %%
statsdf['index_year'].value_counts()
# Out:
# 2020    2732
# 2018    2686
# 2019    2658
# Name: index_year, dtype: int64

# %% [markdown]
# ### Player name

# %%
tfdf3['player'].nunique()
# Out:
# 1024

# %%
statsdf['players'].value_counts()
# Out:
# Raúl García          8
# Adama Traoré         6
# Naldo                6
# Valentin Eysseric    6
# Marcelo              6
#                     ..
# Moritz Bauer         1
# Simon Mignolet       1
# Fabian Bredlow       1
# Joe Bennett          1
# Ariday Cabrera       1
# Name: players, Length: 4018, dtype: int64

# %%
statsdf.loc[statsdf['players']=='Raúl García',['players','nationality','team','position','age','birth_year','index_year','stats_year']]
# Out:
#           players nationality           team position   age  birth_year  \
# 6578  Raúl García      es ESP        Leganés       DF  28.0      1989.0
# 6579  Raúl García      es ESP  Athletic Club    MF,FW  31.0      1986.0
# 7362  Raúl García      es ESP  Athletic Club    MF,FW  32.0      1986.0
# 7363  Raúl García      es ESP         Girona       DF  29.0      1989.0
# 7364  Raúl García      es ESP        Leganés       DF  29.0      1989.0
# 7927  Raúl García      es ESP  Athletic Club    MF,FW  33.0      1986.0
# 7928  Raúl García      es ESP         Getafe       DF  30.0      1989.0
# 7929  Raúl García      es ESP     Valladolid    DF,MF  30.0      1989.0
#
#       index_year stats_year
# 6578        2018  2017-2018
# 6579        2018  2017-2018
# 7362        2019  2018-2019
# 7363        2019  2018-2019
# 7364        2019  2018-2019
# 7927        2020  2019-2020
# 7928        2020  2019-2020
# 7929        2020  2019-2020

# %% [markdown]
# * Looking up Raul Garcia - there is the raul garcia that has been at Bilbao for years.
# * The other 5 entries here are the same Raul Garcia.  He spent time on loan and therefore time at two clubs in 2019 and 2020.
# * Options:
#     - combine the stats from the same year (all % columns will be unuseable)
#     - Only use the stats for the selling club.  This is of course limited, but no more limited than not considering more than one season of work.

# %%
tfdf3['index_name'] = tfdf3['player']

# %%
statsdf['index_name'] = statsdf['players']

# %% [markdown]
# # Merging transfer and stats dataframes by index
#
# ## Original idea
# * Merging on name, nationality, selling club and year (stats year lagged one behind sell year)
# * Did not use age because the timing of the entry in either database was unclear so couldn't get a consistent number lagged or otherwise
# ## Problems with this approach
# * There are players that are transferred multiple times in the same year
#     - e.g.,  Omar Mascarell. Madrid exercised a buy back and then sold (one stats year, two transfers)
#     - e.g., Marc Cucurella. Loaned to Eibar 2018/2019, option to make permanent in summer 2019.  Barca rebought 16 days later and loaned him to Getafe.  Permanently sold to Getafe summer 2020.
#     * IMPACT: We might assume buybacks are set based on the performance prior to their loan but there is nothing in the dataset indicating options to buy (or release fees).  Treating these as independent transactions based on the same performance year.
# * There are players in the stats with multiple observations per year:
#     - Loans/January moves/extended window, e.g., Naldo, Adama Traoré, Rafinha - One full year of stats spread across multiple teams
#     - Mulitple people with same name, nationality, e.g., Naldo which means we can't just sum by player and year
#     - IMPACT: we can't match based on club because of the multi club problem and we can't sum by player and year because of the multi player problem.
# * Solution:
#     - Sum stats df by name, year and dob
#     - This will eliminate all string var from df (will lose nationality, team, position and league) - therefore only left with name and year to merge with transfer data
#     - Individual player profiles on tranfermarkt, have identifying numbers so can't automate the scrap e.g., https://www.transfermarkt.co.uk/nikola-kalinic/profil/spieler/36371
#     - Checked calculating birth year by subtracting age from transfer year - not always correct and likely to lose more data this way than by eliminating ambiguously named/transfer year players.
#     - 2018 6 duplicated names

# %%
statsdf.set_index(['index_name','birth_year','index_year'], inplace=True)

# %%
statsdf3 = statsdf.sum(level=['index_name','birth_year','index_year'])

# %%
statsdf3.head()
# Out:
#                                       age  games  games_start  goals  assists  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018        31.0     27           27      0        2
# Amir Abrashi  1990.0     2018        27.0     12           11      0        0
# René Adler    1985.0     2018        32.0     14           14      0        0
# Ailton        1995.0     2018        22.0      5            1      0        0
# Manuel Akanji 1995.0     2018        22.0     11           10      0        0
#
#                                      pens_successful  pens_attempts  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                      0              0
# Amir Abrashi  1990.0     2018                      0              0
# René Adler    1985.0     2018                      0              0
# Ailton        1995.0     2018                      0              0
# Manuel Akanji 1995.0     2018                      0              0
#
#                                      yellow_cards  red_cards   xg  npxp   xa  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                   3          0  0.5   0.5  0.4
# Amir Abrashi  1990.0     2018                   2          0  0.2   0.2  0.5
# René Adler    1985.0     2018                   0          0  0.0   0.0  0.4
# Ailton        1995.0     2018                   0          0  0.0   0.0  0.2
# Manuel Akanji 1995.0     2018                   2          0  0.2   0.2  0.1
#
#                                      full_90s_played  shots_total  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                   25.6         12.0
# Amir Abrashi  1990.0     2018                    9.4          5.0
# René Adler    1985.0     2018                   14.0          0.0
# Ailton        1995.0     2018                    1.2          1.0
# Manuel Akanji 1995.0     2018                   10.0          5.0
#
#                                      shots_on_target  npxg  passes_completed  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                      1   0.5            1081.0
# Amir Abrashi  1990.0     2018                      0   0.2             260.0
# René Adler    1985.0     2018                      0   0.0             241.0
# Ailton        1995.0     2018                      0   0.0              45.0
# Manuel Akanji 1995.0     2018                      2   0.2             521.0
#
#                                      passes_attempted  passes_total_dist  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                  1313.0            25128.0
# Amir Abrashi  1990.0     2018                   335.0             4482.0
# René Adler    1985.0     2018                   386.0             8770.0
# Ailton        1995.0     2018                    62.0              884.0
# Manuel Akanji 1995.0     2018                   604.0            11385.0
#
#                                      passes_prog_dist  passes_completed_short  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                  7959.0                   241.0
# Amir Abrashi  1990.0     2018                  1183.0                   124.0
# René Adler    1985.0     2018                  5681.0                    20.0
# Ailton        1995.0     2018                   297.0                    20.0
# Manuel Akanji 1995.0     2018                  3396.0                   141.0
#
#                                      passes_attempted_short  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                         275.0
# Amir Abrashi  1990.0     2018                         157.0
# René Adler    1985.0     2018                          22.0
# Ailton        1995.0     2018                          26.0
# Manuel Akanji 1995.0     2018                         161.0
#
#                                      passes_completed_medium  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                          588.0
# Amir Abrashi  1990.0     2018                          104.0
# René Adler    1985.0     2018                           97.0
# Ailton        1995.0     2018                           16.0
# Manuel Akanji 1995.0     2018                          290.0
#
#                                      passes_attempted_medium  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                          655.0
# Amir Abrashi  1990.0     2018                          124.0
# René Adler    1985.0     2018                          102.0
# Ailton        1995.0     2018                           18.0
# Manuel Akanji 1995.0     2018                          314.0
#
#                                      passes_completed_long  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                        243.0
# Amir Abrashi  1990.0     2018                         26.0
# René Adler    1985.0     2018                        124.0
# Ailton        1995.0     2018                          8.0
# Manuel Akanji 1995.0     2018                         88.0
#
#                                      passes_attempted_long  xa_net  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                        369.0     1.6
# Amir Abrashi  1990.0     2018                         42.0    -0.5
# René Adler    1985.0     2018                        262.0    -0.4
# Ailton        1995.0     2018                         15.0    -0.2
# Manuel Akanji 1995.0     2018                        122.0    -0.1
#
#                                      assisted_shots  passes_into_final_third  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                   6.0                     66.0
# Amir Abrashi  1990.0     2018                   4.0                     20.0
# René Adler    1985.0     2018                   1.0                      8.0
# Ailton        1995.0     2018                   2.0                      3.0
# Manuel Akanji 1995.0     2018                   1.0                     39.0
#
#                                      passes_into_penalty_area  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                             3.0
# Amir Abrashi  1990.0     2018                             4.0
# René Adler    1985.0     2018                             0.0
# Ailton        1995.0     2018                             2.0
# Manuel Akanji 1995.0     2018                             3.0
#
#                                      crosses_into_penalty_area  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                              2.0
# Amir Abrashi  1990.0     2018                              1.0
# René Adler    1985.0     2018                              0.0
# Ailton        1995.0     2018                              2.0
# Manuel Akanji 1995.0     2018                              0.0
#
#                                      progressive_passes   sca  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                      91.0  16.0
# Amir Abrashi  1990.0     2018                      30.0  12.0
# René Adler    1985.0     2018                       0.0   2.0
# Ailton        1995.0     2018                       3.0   2.0
# Manuel Akanji 1995.0     2018                      39.0   6.0
#
#                                      sca_passes_live  sca_passes_dead  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                   12.0              1.0
# Amir Abrashi  1990.0     2018                   10.0              0.0
# René Adler    1985.0     2018                    2.0              0.0
# Ailton        1995.0     2018                    2.0              0.0
# Manuel Akanji 1995.0     2018                    4.0              0.0
#
#                                      sca_dribbles  sca_shots  sca_fouled  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                 0.0        3.0         0.0
# Amir Abrashi  1990.0     2018                 0.0        0.0         2.0
# René Adler    1985.0     2018                 0.0        0.0         0.0
# Ailton        1995.0     2018                 0.0        0.0         0.0
# Manuel Akanji 1995.0     2018                 1.0        0.0         0.0
#
#                                      sca_defense  gca  gca_passes_live  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                0.0  2.0              1.0
# Amir Abrashi  1990.0     2018                0.0  1.0              1.0
# René Adler    1985.0     2018                0.0  0.0              0.0
# Ailton        1995.0     2018                0.0  0.0              0.0
# Manuel Akanji 1995.0     2018                1.0  1.0              1.0
#
#                                      gca_passes_dead  gca_dribbles  gca_shots  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                    0.0           0.0        1.0
# Amir Abrashi  1990.0     2018                    0.0           0.0        0.0
# René Adler    1985.0     2018                    0.0           0.0        0.0
# Ailton        1995.0     2018                    0.0           0.0        0.0
# Manuel Akanji 1995.0     2018                    0.0           0.0        0.0
#
#                                      gca_fouled  gca_defense  gca_og_for  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018               0.0          0.0         0.0
# Amir Abrashi  1990.0     2018               0.0          0.0         0.0
# René Adler    1985.0     2018               0.0          0.0         0.0
# Ailton        1995.0     2018               0.0          0.0         0.0
# Manuel Akanji 1995.0     2018               0.0          0.0         0.0
#
#                                      tackles  tackles_won  tackles_def_3rd  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018           43.0         28.0             31.0
# Amir Abrashi  1990.0     2018           37.0         26.0             14.0
# René Adler    1985.0     2018            0.0          0.0              0.0
# Ailton        1995.0     2018            5.0          2.0              3.0
# Manuel Akanji 1995.0     2018           20.0         12.0             14.0
#
#                                      tackles_mid_3rd  tackles_att_3rd  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                   11.0              1.0
# Amir Abrashi  1990.0     2018                   22.0              1.0
# René Adler    1985.0     2018                    0.0              0.0
# Ailton        1995.0     2018                    2.0              0.0
# Manuel Akanji 1995.0     2018                    6.0              0.0
#
#                                      dribble_tackles  dribble_vs  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                   24.0        41.0
# Amir Abrashi  1990.0     2018                   11.0        20.0
# René Adler    1985.0     2018                    0.0         0.0
# Ailton        1995.0     2018                    3.0         7.0
# Manuel Akanji 1995.0     2018                    3.0         8.0
#
#                                      dribbled_past  pressures  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                 17.0      221.0
# Amir Abrashi  1990.0     2018                  9.0      215.0
# René Adler    1985.0     2018                  0.0        2.0
# Ailton        1995.0     2018                  4.0       41.0
# Manuel Akanji 1995.0     2018                  5.0      122.0
#
#                                      pressure_regains  pressures_def_3rd  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                    74.0              148.0
# Amir Abrashi  1990.0     2018                    57.0               71.0
# René Adler    1985.0     2018                     0.0                2.0
# Ailton        1995.0     2018                    12.0               21.0
# Manuel Akanji 1995.0     2018                    46.0               64.0
#
#                                      pressures_mid_3rd  pressures_att_3rd  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                     66.0                7.0
# Amir Abrashi  1990.0     2018                    118.0               26.0
# René Adler    1985.0     2018                      0.0                0.0
# Ailton        1995.0     2018                     15.0                5.0
# Manuel Akanji 1995.0     2018                     52.0                6.0
#
#                                      blocks  blocked_shots  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018          39.0           16.0
# Amir Abrashi  1990.0     2018          20.0            5.0
# René Adler    1985.0     2018           0.0            0.0
# Ailton        1995.0     2018           5.0            0.0
# Manuel Akanji 1995.0     2018          14.0            4.0
#
#                                      blocked_shots_saves  blocked_passes  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                        0.0            23.0
# Amir Abrashi  1990.0     2018                        0.0            15.0
# René Adler    1985.0     2018                        0.0             0.0
# Ailton        1995.0     2018                        0.0             5.0
# Manuel Akanji 1995.0     2018                        0.0            10.0
#
#                                      interceptions  tackles_interceptions  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                 23.0                     66
# Amir Abrashi  1990.0     2018                 11.0                     48
# René Adler    1985.0     2018                  0.0                      0
# Ailton        1995.0     2018                  1.0                      6
# Manuel Akanji 1995.0     2018                  7.0                     27
#
#                                      clearances  errors  touches  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018             130.0     1.0   1561.0
# Amir Abrashi  1990.0     2018              19.0     2.0    471.0
# René Adler    1985.0     2018               4.0     0.0    442.0
# Ailton        1995.0     2018               1.0     0.0     83.0
# Manuel Akanji 1995.0     2018              58.0     0.0    720.0
#
#                                      touches_def_pen_area  touches_def_3rd  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                       151.0            830.0
# Amir Abrashi  1990.0     2018                        28.0            122.0
# René Adler    1985.0     2018                       334.0            440.0
# Ailton        1995.0     2018                         3.0             23.0
# Manuel Akanji 1995.0     2018                        56.0            312.0
#
#                                      touches_mid_3rd  touches_att_3rd  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                  844.0             43.0
# Amir Abrashi  1990.0     2018                  288.0             80.0
# René Adler    1985.0     2018                    3.0              0.0
# Ailton        1995.0     2018                   50.0             14.0
# Manuel Akanji 1995.0     2018                  422.0             65.0
#
#                                      touches_att_pen_area  touches_live_ball  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                        13.0             1526.0
# Amir Abrashi  1990.0     2018                         9.0              467.0
# René Adler    1985.0     2018                         0.0              333.0
# Ailton        1995.0     2018                         3.0               72.0
# Manuel Akanji 1995.0     2018                        10.0              688.0
#
#                                      dribbles_completed  dribbles  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                      13.0      14.0
# Amir Abrashi  1990.0     2018                       5.0      11.0
# René Adler    1985.0     2018                       0.0       0.0
# Ailton        1995.0     2018                       1.0       3.0
# Manuel Akanji 1995.0     2018                       6.0       7.0
#
#                                      players_dribbled_past  nutmegs  carries  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                         13.0      0.0    955.0
# Amir Abrashi  1990.0     2018                          7.0      0.0    277.0
# René Adler    1985.0     2018                          0.0      0.0    237.0
# Ailton        1995.0     2018                          1.0      0.0     48.0
# Manuel Akanji 1995.0     2018                          6.0      0.0    477.0
#
#                                      carry_distance  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                6200.0
# Amir Abrashi  1990.0     2018                1277.0
# René Adler    1985.0     2018                1236.0
# Ailton        1995.0     2018                 297.0
# Manuel Akanji 1995.0     2018                3592.0
#
#                                      carry_progressive_distance  pass_targets  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                            3493.0         903.0
# Amir Abrashi  1990.0     2018                             553.0         266.0
# René Adler    1985.0     2018                             652.0         171.0
# Ailton        1995.0     2018                             189.0          53.0
# Manuel Akanji 1995.0     2018                            2112.0         486.0
#
#                                      passes_received  miscontrols  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                  890.0          5.0
# Amir Abrashi  1990.0     2018                  230.0          9.0
# René Adler    1985.0     2018                  171.0          0.0
# Ailton        1995.0     2018                   46.0          3.0
# Manuel Akanji 1995.0     2018                  477.0          5.0
#
#                                      dispossessed  passes_left_foot  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                 6.0             208.0
# Amir Abrashi  1990.0     2018                14.0              18.0
# René Adler    1985.0     2018                 0.0              39.0
# Ailton        1995.0     2018                 0.0              46.0
# Manuel Akanji 1995.0     2018                 3.0             142.0
#
#                                      passes_right_foot  aerials_won  \
# index_name    birth_year index_year
# David Abraham 1986.0     2018                    923.0         62.0
# Amir Abrashi  1990.0     2018                    272.0         21.0
# René Adler    1985.0     2018                    284.0          0.0
# Ailton        1995.0     2018                      3.0          2.0
# Manuel Akanji 1995.0     2018                    394.0         17.0
#
#                                      aerials_lost  mins_num
# index_name    birth_year index_year
# David Abraham 1986.0     2018                26.0      2302
# Amir Abrashi  1990.0     2018                19.0       850
# René Adler    1985.0     2018                 1.0      1260
# Ailton        1995.0     2018                 3.0       108
# Manuel Akanji 1995.0     2018                17.0       904

# %%
print(statsdf.shape)
print(statsdf3.shape)
# Out:
# (8076, 98)
# (7732, 91)

# %%
statsdf3.reset_index(inplace=True)

# %%
# Checked calculation against some random profiles - inaccurate.
# tfdf3['birth_year'] = tfdf3['transfer_year'] - tfdf3['age']
# tfdf3.loc[:,['player','age','birth_year']]

# %% [markdown]
# # Preping for merge
# * Because I can't easily scrape dob or calculate birth year in the transfer df in the below I check how many names are repeated in the statsdf by year (the merging levels) and cross-referencing against entries in the transfer df
#
# * 2018: Naldo sold from schalke to monaco (delete index 6505)
# * Not sold in year: Raúl García, Juanfran, Rafinha, Marcelo, Rafael sold
#
# * 2019:
# * Not sold in year: Nacho, Allan, Manu García, Adama Traoré, Marcelo, Raúl García, Sergio Álvarez, Juanfran
#
# * 2020:
# * Not sold in year: Javi Martinez, Adama Traoré, Sergio Álvarez, Marcelo, Jonas Hofmann, Pedro, Javi López, Raúl García, Nacho, João Pedro, Rafael, Ibrahim Cissé

# %%
statsdf3.drop(index=6505, inplace=True)

# %%
#assessing individual names to make them unambiguous
# tfdf3['index_name'].value_counts()

# %%
# tfdf3.loc[tfdf3['index_name']=='Coke']

# %%
# statsdf3.loc[statsdf3['index_name']=='Coke']

# %%
#Gabriel uses different name between df's
tfdf3.loc[(tfdf3['index_name']=='Gabriel')&(tfdf3['selling_club']=='LOSC Lille'), ['player','index_name']] = 'Gabriel Dos Santos'

# %%
#Danilo Larangeira
tfdf3.loc[(tfdf3['index_name']=='Danilo')&(tfdf3['selling_club']=='Udinese Calcio'), ['player','index_name']] = 'Danilo Larangeira'

# %%
#Arthur Melo
tfdf3.loc[(tfdf3['index_name']=='Arthur')&(tfdf3['selling_club']=='FC Barcelona'), ['player','index_name']] = 'Arthur Melo'

# %%
#Thiago Alcántara
tfdf3.loc[(tfdf3['index_name']=='Thiago')&(tfdf3['selling_club']=='Bayern Munich'), ['player','index_name']] = 'Thiago Alcántara'

# %%
# Raphael Dias Belloli
tfdf3.loc[(tfdf3['index_name']=='Raphinha')&(tfdf3['selling_club']=='Stade Rennais FC'), ['player','index_name']] = 'Raphael Dias Belloli'

# %%
# Kepa Arrizabalaga
tfdf3.loc[(tfdf3['index_name']=='Kepa')&(tfdf3['selling_club']=='Athletic Bilbao'), ['player','index_name']] = 'Kepa Arrizabalaga'

# %%
#Chicarito/ Javier Hernández
tfdf3.loc[(tfdf3['index_name']=='Chicharito')&(tfdf3['selling_club']=='West Ham United'), ['player','index_name']] = 'Javier Hernández'

# %%
#Fernando Marçal
tfdf3.loc[(tfdf3['index_name']=='Marçal')&(tfdf3['selling_club']=='Olympique Lyon'), ['player','index_name']] = 'Fernando Marçal'

# %%
#Vagner Gonçalves - he spent 2018/2019 2019/2020 in second division (no stats)
tfdf3.loc[(tfdf3['index_name']=='Vagner')&(tfdf3['selling_club']=='AS Saint-Étienne'), ['player','index_name']] = 'Vagner Gonçalves'

# %%
#Fixing data entry errors for age:
statsdf3.loc[(statsdf3['index_name']=='Suso')&(statsdf3['index_year']==2020), 'age'] = 25
statsdf3.loc[(statsdf3['index_name']=='Sandro')&(statsdf3['index_year']==2019), 'age'] = 29
statsdf3.loc[(statsdf3['index_name']=='Javier Hernández')&(statsdf3['index_year']==2020), 'age'] = 31
statsdf3.loc[(statsdf3['index_name']=='Coke')&(statsdf3['index_year']==2018), 'age'] = 30

# %%
df = tfdf3.merge(statsdf3, on=['index_name','index_year'])

# %%
df.shape
# Out:
# (678, 114)

# %%
df.to_csv('data/transfers_and_stats_merged.csv')

# %% [markdown]
# ## Variable creation no longer needed
# * Harmonizing nationality and selling club

# %% [markdown]
# Creating a dictionary of country abbreviations to create a new column in the stats df that is the full name of the nation to facilitate index matching with nationality in the transfer df

# %%
#from: https://www.realifewebdesigns.com/web-marketing/abbreviations-countries.asp
# country_abb = pd.read_excel('data/country_abbreviations.xlsx', header=None)

# %%
#format: "AF = Afghanistan"
#extracting the country code abbreviation and country name as key and value for dictionary
# country_abb['key'] = country_abb[0].apply(lambda x: x[0:2].lower())
# country_abb['value'] = country_abb[0].apply(lambda x: x[4:])

# %%
#dropping original column
# country_abb.drop(labels=0, axis=1, inplace=True)

# %%
#Convert series to lists to facilitate creation of dictionary
# key_list = list(country_abb['key'])
# value_list = list(country_abb['value'])

# %%
# country_dict = {}
# for n in range(len(key_list)):
#     country_dict[key_list[n]] = value_list[n]

# %%
#Extracting the abbreviation from the nationality column (formatting as "ar ARG")
# statsdf['nationality_abb'] = statsdf['nationality'].str.extract(r'([a-z]+)')

# %%
#the entries for guadelupe were missing the two letter code
#French guiana's code is GUF, the one GYF is a data entry error correcting here
#explains the nunique discrepancy 
# statsdf.loc[statsdf['nationality'] == ' GPE', 'nationality_abb'] = 'gp' 
# statsdf.loc[statsdf['nationality'] == ' GYF', 'nationality_abb'] = 'gf'

# %%
# print(statsdf['nationality'].nunique())
# print(statsdf['nationality_abb'].nunique())

# print(statsdf['nationality'].value_counts())
# print(statsdf['nationality_abb'].value_counts())

# %%
#Manually entering missing abbreviations from the list from the website to faciliate recoding:
# country_dict['cw'] = 'Curacao'
# country_dict['eng'] = 'England'
# country_dict['is'] = 'Iceland'
# country_dict['rs'] = 'Serbia'
# country_dict['xk'] = 'Kosovo'
# country_dict['wal'] = 'Wales'
# country_dict['sco'] = 'Scotland'
# country_dict['nir'] = 'Northern Ireland'
# country_dict['me'] = 'Montenegro'

# %%
# statsdf['index_nationality'] = statsdf['nationality_abb'].map(lambda x: country_dict[x])

# %%
# tfdf3['index_nationality'] = tfdf3['nationality']

# %% [markdown]
# ## Indexing on selling club in transfer data and club in stats data

# %% [markdown]
# * The previous league column in tfdf3 is more correctly previous country.  Therefore includes purchases from lower leagues and academies not just top tier.  Therefore tfdf3 has more clubs than appear in the stats dataset.  The team in statsdf is the more generic version.
# * Import a dictionary with generic name as key and full name as value from pyfiles to add to the statsdf for index matching.

# %%
# import py_files.team_dictionary as team_dict

# %%
# team_dict = team_dict.team_dict

# %%
# statsdf['index_selling_club'] = statsdf['team'].map(lambda x: team_dict[x])

# %%
# tfdf3['index_selling_club'] = tfdf3['selling_club']
