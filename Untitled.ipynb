# %%
import pandas as pd

# %%
df = pd.read_csv('Prem_summer_2020.csv')
df
# Out:
#      Unnamed: 0                player  age nationality            position  \
# 0             0         Thomas Partey   27       Ghana  Defensive Midfield
# 1             1               Gabriel   22      Brazil         Centre-Back
# 2             2            Pablo Marí   26       Spain         Centre-Back
# 3             3  Rúnar Alex Rúnarsson   25     Iceland          Goalkeeper
# 4             4         Cédric Soares   28    Portugal          Right-Back
# ..          ...                   ...  ...         ...                 ...
# 274          10        Renat Dadashov   21  Azerbaijan      Centre-Forward
# 275          11          Hélder Costa   26    Portugal        Right Winger
# 276          12          Léo Bonatini   26      Brazil      Centre-Forward
# 277          13      Roderick Miranda   29    Portugal         Centre-Back
# 278          14          Ryan Bennett   30     England         Centre-Back
#
# ...

# %%
df.drop(columns='Unnamed: 0',inplace=True)

# %%
df.to_csv('../data/Prem_summer_2020.csv',index=False)
# Out:
# ---------------------------------------------------------------------------
# NotADirectoryError                        Traceback (most recent call last)
# <ipython-input-5-8ee34b2c0d86> in <module>()
# ----> 1 df.to_csv('../data/Prem_summer_2020.csv',index=False)
#
# /Users/ericroberts/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core/generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3226             decimal=decimal,
#    3227         )
# -> 3228         formatter.save()
#    3229
#    3230         if path_or_buf is None:
#
# /Users/ericroberts/anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/io/formats/csvs.py in save(self)
#     181                 self.mode,
#     182                 encoding=self.encoding,
# --> 183                 compression=self.compression,
# ...
